# %%
from T1_1_Functions import result_plot, result_plot_unnormalized
import pickle as pkl
import os

folder_dir= 'dicts'

result_file_name = "Exp_0_Exact - NonNormalizedConstStatRealData_result.pkl"
result_file_dir = os.path.join(folder_dir, result_file_name)

with open(result_file_dir, "rb") as pickle_file:
    result_dict_imported = pkl.load(pickle_file)
    
result_file_name_r = "Exp_0_Robust - NonNormalizedConstStatRealData_result.pkl"
result_file_dir_r = os.path.join(folder_dir, result_file_name_r)

with open(result_file_dir_r, "rb") as pickle_file:
    result_dict_imported_r = pkl.load(pickle_file)

result_plot_unnormalized(
                        y_train            = result_dict_imported["y_train"],
                        datascaler         = result_dict_imported["datascaler"],
                        x_b_sim_neural     = result_dict_imported["x_b_sim_neural"],
                        x_f_sim_neural     = result_dict_imported["x_f_sim_neural"],
                        datascaler_r       = result_dict_imported_r["datascaler"],
                        x_b_sim_neural_r   = result_dict_imported_r["x_b_sim_neural"],
                        x_f_sim_neural_r   = result_dict_imported_r["x_f_sim_neural"],
                        save_figs=True
                        )
