# %%
from Launcher import launch_greyboxmodel
from Functions import result_plot
import torch
from torch import nn as nn


####################################################################################################################################################################
## Constants

neuron_dict =   {
                "f_b": [8, 8],
                "g_b": [8, 8], 
                "h_b": [8],  
                }

act_fn_dict =   {
                "f_b": nn.Tanh(),
                "g_b": nn.Tanh(), 
                "h_b": nn.Tanh(),  
                }

optim_alg_dict =    {
                    "physical optimization algorithm": torch.optim.AdamW,
                    "neural optimization algorithm": torch.optim.AdamW,  
                    }

lr_neuralnet =  {
                "f_b": 1e-2,
                "g_b": 5e-2,
                "h_b": 1e-2
                }

iv_est_dict = {"Physical Estimate": {}} 

init_std   = 1e-2
lr_theta_f = 1e-2
lr_x0_phys = 1e-2
lr_mu_x    = 1e-3
lr_sigma_x = 1e-3

x_b_exploration_scale = 100
neuron_dict = neuron_dict
optim_alg_dict = optim_alg_dict
act_fn_dict = act_fn_dict
 
# device = set_least_used_device()
device = torch.device('cpu')
seed = 42

####################################################################################################################################################################
# Experiments Settings
## Cosmetics
display_step  = 1

## Low-Key Variables
epochs_phys   = 10
epochs_neural = 100

## High-Key Variables
augmentation  = "Exact - MANAM"
gamma_power = 0.1

y_pred_test, y_pred_test_lin, augmodel, result_dict, linmodel, model, execution_time  = launch_greyboxmodel(epochs_neural=epochs_neural,
                                                                                        epochs_phys=epochs_phys,
                                                                                        lr_neuralnet = lr_neuralnet,
                                                                                        lr_theta_f=lr_theta_f,
                                                                                        lr_x0_phys=lr_x0_phys,
                                                                                        lr_mu_x = lr_mu_x,
                                                                                        lr_sigma_x = lr_sigma_x,
                                                                                        augmentation=augmentation,
                                                                                        x_b_exploration_scale=x_b_exploration_scale,
                                                                                        init_std=init_std,
                                                                                        neuron_dict=neuron_dict,
                                                                                        optim_alg_dict = optim_alg_dict,
                                                                                        act_fn_dict=act_fn_dict,
                                                                                        display_step=display_step,
                                                                                        device = device,
                                                                                        seed = seed,
                                                                                        iv_est_dict=iv_est_dict,
                                                                                        gamma_power=gamma_power) 



# Plotting the results
result_plot(datascaler      = result_dict["datascaler"],
            y_train         = result_dict["y_train"],
            y_val           = result_dict["y_val"],
            y_test          = result_dict["y_test"],
            y_sim_phys      = result_dict["y_sim_phys"],
            y_val_phys      = result_dict["y_val_phys"],
            y_test_phys     = result_dict["y_test_phys"],
            y_sim_neural    = result_dict["y_sim_neural"],
            y_val_neural    = result_dict["y_val_neural"],
            y_test_neural   = result_dict["y_test_neural"],
            x_b_sim_neural  = result_dict["x_b_sim_neural"],
            x_b_val_neural  = result_dict["x_b_val_neural"],
            x_b_test_neural = result_dict["x_b_test_neural"],
            x_f_sim_neural  = result_dict["x_f_sim_neural"],
            x_f_val_neural  = result_dict["x_f_val_neural"],
            x_f_test_neural = result_dict["x_f_test_neural"])
